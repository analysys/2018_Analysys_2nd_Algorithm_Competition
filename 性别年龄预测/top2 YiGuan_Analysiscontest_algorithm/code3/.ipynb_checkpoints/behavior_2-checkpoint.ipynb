# %%
import gc
import time
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from help_function import LoadData
import warnings
warnings.filterwarnings('ignore')

# %%
# 行为数据
behavior = pd.read_csv('../Demo/deviceid_package_start_close.tsv',sep='\t',
                       names = ['device_id','app_id','start','close'])

# 应用label数据
app_label = pd.read_csv('../Demo/package_label.tsv',sep='\t',
                        names=['app_id','label_1','label_2'])
app_label.label_1 = app_label.label_1.apply(lambda x:x.split('(')[0])
app_label.label_2 = app_label.label_2.apply(lambda x:x.split('/')[0])

# %%
# trian data , test data
# train test data
train_datapath =  '../Demo/deviceid_train.tsv' 
test_datapath =  '../Demo/deviceid_test.tsv' 
train_data, test_data = LoadData(train_datapath, test_datapath)

# %% [markdown]
# ## start , close

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
vectorizer=CountVectorizer()

# %%
def TransTt2Hour(x):
    timeArray = time.localtime(float(x)/1000)
    otherStyleTime = time.strftime('%H', timeArray)
    return str(otherStyleTime)
def ret_list(arr):
    return list(arr)

# %%
behavior['s_hour'] = behavior.start.apply(TransTt2Hour)
behavior['c_hour'] = behavior.close.apply(TransTt2Hour)

# %%
# group-obj
group_obj = behavior.groupby(by='device_id')
features = pd.DataFrame({'device_id':behavior.device_id.unique()})

# %% [markdown]
# ### start : s_hour

# %%
groupfeature = group_obj.s_hour.agg(ret_list).reset_index()

groupfeature.rename(index=str,columns={0:'s_hour'},inplace=True)

s_hours = groupfeature.s_hour.apply(lambda x:' '.join(x)).tolist()

sh_vector = vectorizer.fit_transform(s_hours)

# cntvector
f_names = ['s'+str(x) for x in range(24)]
sh_vector = pd.DataFrame(sh_vector.toarray(),columns=f_names)

sh_vector['device_id'] = groupfeature.device_id.values

# %% [markdown]
# ### close : c_hour

# %%
groupfeature = group_obj.c_hour.agg(ret_list).reset_index()

groupfeature.rename(index=str,columns={0:'c_hour'},inplace=True)

c_hours = groupfeature.c_hour.apply(lambda x:' '.join(x)).tolist()

ch_vector = vectorizer.fit_transform(c_hours)

f_names = ['c'+str(x) for x in range(24)]
ch_vector = pd.DataFrame(ch_vector.toarray(),columns=f_names)

ch_vector['device_id'] = groupfeature.device_id.values

# %%
# s_hour + c_hour
sc_vector = sh_vector.merge(ch_vector, on='device_id', how='left')
sc_vector.to_csv('features/h3.csv',index=False)

# %%
train_set = train_data.merge(sc_vector, on='device_id', how='left')
test_set = test_data.merge(sc_vector, on='device_id', how='left')

# %% [markdown]
# train code

# %%
def xgbc_code(train_data, test_data,label, num_class, n_folds=5,
              obj='multi:softprob', metric='mlogloss'):
    labels = train_data[[label]]
    train_data = train_data.drop(['device_id','sex','age','label'],axis=1)
    test_data = test_data.drop(['device_id'],axis=1)
    train_predvec = np.zeros((train_data.shape[0], num_class))
    test_predvec = np.zeros((test_data.shape[0], num_class))
    SKF = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = 2018)
    train_logloss = []
    valid_logloss = []
    for train_indices, valid_indices in SKF.split(train_data,labels):
        # Training data for the fold
        x_train = train_data.loc[train_indices, :]
        y_train = labels.loc[train_indices, :]
        # Validation data for the fold
        x_valid = train_data.loc[valid_indices, :]
        y_valid = labels.loc[valid_indices, :]
        # XGboost
        xgbc = xgb.XGBClassifier(max_depth=3, learning_rate=0.09, n_estimators=1000,
                         silent=True, objective = obj,
                         booster='gbtree', n_jobs=-1,
                         gamma=0, subsample=1,
                         colsample_bytree=0.6, colsample_bylevel=1.,
                         reg_alpha=0, reg_lambda=1,
                         scale_pos_weight=1,
                         base_score=0.5,
                         max_delta_step = 0,
                         random_state=666)
        xgbc.fit(x_train, y_train,
                 eval_set=[(x_train, y_train),(x_valid, y_valid)],
                 eval_metric = metric,
                 early_stopping_rounds=10,
                 verbose=0)
        # record logloss
        train_logloss.append(log_loss(y_train, xgbc.predict_proba(x_train)))
        valid_logloss.append(log_loss(y_valid, xgbc.predict_proba(x_valid)))
        train_predvec[valid_indices] = xgbc.predict_proba(x_valid)
        test_predvec += xgbc.predict_proba(test_data)/n_folds
        # Clean up memory
        gc.enable()
        del xgbc, x_train, y_train, x_valid, y_valid
        gc.collect()
        print('############## one flod is over ##############')
    train_logloss.append(np.mean(train_logloss))
    valid_logloss.append(log_loss(labels, train_predvec))
    # dataframe of validation scores
    fold_names = list(range(n_folds))
    fold_names.append('overall')
    # Dataframe of validation scores
    metrics = pd.DataFrame({'fold': fold_names,
                            'train_logloss':train_logloss,
                            'valid_logloss':valid_logloss})
    return metrics, train_predvec, test_predvec

# %%
# sex+age   num_class = 22
metric, train_1, test_1 = xgbc_code(train_set, test_set, 'label', 22, 10)
# Out:
# [0]	validation_0-mlogloss:3.06968	validation_1-mlogloss:3.07154
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93741	validation_1-mlogloss:2.95323
# [20]	validation_0-mlogloss:2.87419	validation_1-mlogloss:2.902
# [30]	validation_0-mlogloss:2.83903	validation_1-mlogloss:2.87767
# [40]	validation_0-mlogloss:2.81638	validation_1-mlogloss:2.86526
# [50]	validation_0-mlogloss:2.8004	validation_1-mlogloss:2.85862
# [60]	validation_0-mlogloss:2.78769	validation_1-mlogloss:2.85486
# [70]	validation_0-mlogloss:2.77683	validation_1-mlogloss:2.85286
# [80]	validation_0-mlogloss:2.76717	validation_1-mlogloss:2.85167
# [90]	validation_0-mlogloss:2.75832	validation_1-mlogloss:2.85115
# [100]	validation_0-mlogloss:2.74997	validation_1-mlogloss:2.85054
# [110]	validation_0-mlogloss:2.74191	validation_1-mlogloss:2.85043
# Stopping. Best iteration:
# [104]	validation_0-mlogloss:2.74663	validation_1-mlogloss:2.85025
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06969	validation_1-mlogloss:3.07133
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93735	validation_1-mlogloss:2.95174
# [20]	validation_0-mlogloss:2.87421	validation_1-mlogloss:2.8999
# [30]	validation_0-mlogloss:2.83898	validation_1-mlogloss:2.87425
# [40]	validation_0-mlogloss:2.81664	validation_1-mlogloss:2.86184
# [50]	validation_0-mlogloss:2.80037	validation_1-mlogloss:2.85548
# [60]	validation_0-mlogloss:2.78743	validation_1-mlogloss:2.85186
# [70]	validation_0-mlogloss:2.77649	validation_1-mlogloss:2.85011
# [80]	validation_0-mlogloss:2.7667	validation_1-mlogloss:2.84891
# [90]	validation_0-mlogloss:2.75753	validation_1-mlogloss:2.84836
# [100]	validation_0-mlogloss:2.74904	validation_1-mlogloss:2.84842
# Stopping. Best iteration:
# [99]	validation_0-mlogloss:2.74991	validation_1-mlogloss:2.84823
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06985	validation_1-mlogloss:3.07155
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93751	validation_1-mlogloss:2.95294
# [20]	validation_0-mlogloss:2.87432	validation_1-mlogloss:2.90079
# [30]	validation_0-mlogloss:2.83938	validation_1-mlogloss:2.87558
# [40]	validation_0-mlogloss:2.81716	validation_1-mlogloss:2.86369
# [50]	validation_0-mlogloss:2.80128	validation_1-mlogloss:2.85692
# [60]	validation_0-mlogloss:2.78846	validation_1-mlogloss:2.85312
# [70]	validation_0-mlogloss:2.77763	validation_1-mlogloss:2.85117
# [80]	validation_0-mlogloss:2.76805	validation_1-mlogloss:2.85048
# [90]	validation_0-mlogloss:2.75906	validation_1-mlogloss:2.84977
# [100]	validation_0-mlogloss:2.7504	validation_1-mlogloss:2.84908
# [110]	validation_0-mlogloss:2.742	validation_1-mlogloss:2.84889
# [120]	validation_0-mlogloss:2.73411	validation_1-mlogloss:2.84874
# [130]	validation_0-mlogloss:2.72636	validation_1-mlogloss:2.84937
# Stopping. Best iteration:
# [121]	validation_0-mlogloss:2.73324	validation_1-mlogloss:2.84866
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06993	validation_1-mlogloss:3.07107
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93801	validation_1-mlogloss:2.95006
# [20]	validation_0-mlogloss:2.87497	validation_1-mlogloss:2.89681
# [30]	validation_0-mlogloss:2.83957	validation_1-mlogloss:2.87141
# [40]	validation_0-mlogloss:2.81725	validation_1-mlogloss:2.8586
# [50]	validation_0-mlogloss:2.80111	validation_1-mlogloss:2.85141
# [60]	validation_0-mlogloss:2.78834	validation_1-mlogloss:2.84789
# [70]	validation_0-mlogloss:2.77741	validation_1-mlogloss:2.84591
# [80]	validation_0-mlogloss:2.76773	validation_1-mlogloss:2.84502
# [90]	validation_0-mlogloss:2.75887	validation_1-mlogloss:2.84432
# [100]	validation_0-mlogloss:2.75028	validation_1-mlogloss:2.84391
# [110]	validation_0-mlogloss:2.74211	validation_1-mlogloss:2.84351
# [120]	validation_0-mlogloss:2.73419	validation_1-mlogloss:2.84361
# Stopping. Best iteration:
# [117]	validation_0-mlogloss:2.73646	validation_1-mlogloss:2.84335
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06988	validation_1-mlogloss:3.07132
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93806	validation_1-mlogloss:2.95121
# [20]	validation_0-mlogloss:2.87514	validation_1-mlogloss:2.89769
# [30]	validation_0-mlogloss:2.84014	validation_1-mlogloss:2.87134
# [40]	validation_0-mlogloss:2.81781	validation_1-mlogloss:2.85868
# [50]	validation_0-mlogloss:2.80195	validation_1-mlogloss:2.85138
# [60]	validation_0-mlogloss:2.78937	validation_1-mlogloss:2.84782
# [70]	validation_0-mlogloss:2.77847	validation_1-mlogloss:2.84566
# [80]	validation_0-mlogloss:2.76889	validation_1-mlogloss:2.84412
# [90]	validation_0-mlogloss:2.75994	validation_1-mlogloss:2.84362
# [100]	validation_0-mlogloss:2.75128	validation_1-mlogloss:2.84314
# [110]	validation_0-mlogloss:2.7434	validation_1-mlogloss:2.84315
# Stopping. Best iteration:
# [103]	validation_0-mlogloss:2.74892	validation_1-mlogloss:2.84306
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06994	validation_1-mlogloss:3.07094
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93836	validation_1-mlogloss:2.94841
# [20]	validation_0-mlogloss:2.87575	validation_1-mlogloss:2.8933
# [30]	validation_0-mlogloss:2.84061	validation_1-mlogloss:2.86621
# [40]	validation_0-mlogloss:2.81826	validation_1-mlogloss:2.85243
# [50]	validation_0-mlogloss:2.80202	validation_1-mlogloss:2.84445
# [60]	validation_0-mlogloss:2.78934	validation_1-mlogloss:2.83979
# [70]	validation_0-mlogloss:2.77867	validation_1-mlogloss:2.83686
# [80]	validation_0-mlogloss:2.76901	validation_1-mlogloss:2.83576
# [90]	validation_0-mlogloss:2.75997	validation_1-mlogloss:2.83498
# [100]	validation_0-mlogloss:2.75173	validation_1-mlogloss:2.83436
# [110]	validation_0-mlogloss:2.74388	validation_1-mlogloss:2.83424
# [120]	validation_0-mlogloss:2.7359	validation_1-mlogloss:2.83419
# Stopping. Best iteration:
# [114]	validation_0-mlogloss:2.7406	validation_1-mlogloss:2.83402
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06985	validation_1-mlogloss:3.0709
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93821	validation_1-mlogloss:2.94942
# [20]	validation_0-mlogloss:2.87547	validation_1-mlogloss:2.89632
# [30]	validation_0-mlogloss:2.84075	validation_1-mlogloss:2.86965
# [40]	validation_0-mlogloss:2.81835	validation_1-mlogloss:2.85599
# [50]	validation_0-mlogloss:2.80202	validation_1-mlogloss:2.84881
# [60]	validation_0-mlogloss:2.78919	validation_1-mlogloss:2.84474
# [70]	validation_0-mlogloss:2.77846	validation_1-mlogloss:2.8428
# [80]	validation_0-mlogloss:2.76882	validation_1-mlogloss:2.84175
# [90]	validation_0-mlogloss:2.75946	validation_1-mlogloss:2.84104
# [100]	validation_0-mlogloss:2.75093	validation_1-mlogloss:2.84099
# [110]	validation_0-mlogloss:2.74281	validation_1-mlogloss:2.84078
# [120]	validation_0-mlogloss:2.73459	validation_1-mlogloss:2.84063
# [130]	validation_0-mlogloss:2.72688	validation_1-mlogloss:2.84025
# [140]	validation_0-mlogloss:2.71936	validation_1-mlogloss:2.84004
# Stopping. Best iteration:
# [139]	validation_0-mlogloss:2.72004	validation_1-mlogloss:2.84
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.0698	validation_1-mlogloss:3.07153
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93698	validation_1-mlogloss:2.95331
# [20]	validation_0-mlogloss:2.87378	validation_1-mlogloss:2.90172
# [30]	validation_0-mlogloss:2.83851	validation_1-mlogloss:2.87696
# [40]	validation_0-mlogloss:2.81581	validation_1-mlogloss:2.86488
# [50]	validation_0-mlogloss:2.79969	validation_1-mlogloss:2.85785
# [60]	validation_0-mlogloss:2.78694	validation_1-mlogloss:2.85449
# [70]	validation_0-mlogloss:2.77597	validation_1-mlogloss:2.85242
# [80]	validation_0-mlogloss:2.76603	validation_1-mlogloss:2.85129
# [90]	validation_0-mlogloss:2.75691	validation_1-mlogloss:2.85059
# [100]	validation_0-mlogloss:2.74832	validation_1-mlogloss:2.85026
# [110]	validation_0-mlogloss:2.74017	validation_1-mlogloss:2.84997
# [120]	validation_0-mlogloss:2.73233	validation_1-mlogloss:2.84961
# Stopping. Best iteration:
# [117]	validation_0-mlogloss:2.73465	validation_1-mlogloss:2.84943
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.0698	validation_1-mlogloss:3.07119
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93756	validation_1-mlogloss:2.95269
# [20]	validation_0-mlogloss:2.87464	validation_1-mlogloss:2.90044
# [30]	validation_0-mlogloss:2.8396	validation_1-mlogloss:2.87514
# [40]	validation_0-mlogloss:2.81708	validation_1-mlogloss:2.86308
# [50]	validation_0-mlogloss:2.80113	validation_1-mlogloss:2.85621
# [60]	validation_0-mlogloss:2.78819	validation_1-mlogloss:2.85278
# [70]	validation_0-mlogloss:2.77748	validation_1-mlogloss:2.85123
# [80]	validation_0-mlogloss:2.76795	validation_1-mlogloss:2.85052
# [90]	validation_0-mlogloss:2.75901	validation_1-mlogloss:2.8499
# [100]	validation_0-mlogloss:2.75009	validation_1-mlogloss:2.84961
# [110]	validation_0-mlogloss:2.74173	validation_1-mlogloss:2.84972
# Stopping. Best iteration:
# [107]	validation_0-mlogloss:2.74398	validation_1-mlogloss:2.84943
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:3.06979	validation_1-mlogloss:3.07155
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.93754	validation_1-mlogloss:2.95324
# [20]	validation_0-mlogloss:2.87458	validation_1-mlogloss:2.90038
# [30]	validation_0-mlogloss:2.8394	validation_1-mlogloss:2.87487
# [40]	validation_0-mlogloss:2.81725	validation_1-mlogloss:2.86189
# [50]	validation_0-mlogloss:2.80144	validation_1-mlogloss:2.85501
# [60]	validation_0-mlogloss:2.78871	validation_1-mlogloss:2.851
# [70]	validation_0-mlogloss:2.77779	validation_1-mlogloss:2.8487
# [80]	validation_0-mlogloss:2.76819	validation_1-mlogloss:2.84771
# [90]	validation_0-mlogloss:2.75911	validation_1-mlogloss:2.84666
# [100]	validation_0-mlogloss:2.7505	validation_1-mlogloss:2.84633
# [110]	validation_0-mlogloss:2.74235	validation_1-mlogloss:2.84559
# [120]	validation_0-mlogloss:2.73415	validation_1-mlogloss:2.84506
# [130]	validation_0-mlogloss:2.72647	validation_1-mlogloss:2.8453
# Stopping. Best iteration:
# [121]	validation_0-mlogloss:2.7334	validation_1-mlogloss:2.84502
#
# ############## one flod is over ##############

# %%
np.save('new_feature/h3_train.npy',train_1)
np.save('new_feature/h3_test.npy',test_1)

# %%
# age num_class = 11
metric, age_train, age_test = xgbc_code(train_set, test_set, 'age', 11, 10)
# Out:
# [0]	validation_0-mlogloss:2.38286	validation_1-mlogloss:2.38348
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28572	validation_1-mlogloss:2.29291
# [20]	validation_0-mlogloss:2.23827	validation_1-mlogloss:2.25077
# [30]	validation_0-mlogloss:2.21197	validation_1-mlogloss:2.22957
# [40]	validation_0-mlogloss:2.19587	validation_1-mlogloss:2.21863
# [50]	validation_0-mlogloss:2.1849	validation_1-mlogloss:2.21245
# [60]	validation_0-mlogloss:2.17675	validation_1-mlogloss:2.20877
# [70]	validation_0-mlogloss:2.17004	validation_1-mlogloss:2.20652
# [80]	validation_0-mlogloss:2.16418	validation_1-mlogloss:2.20501
# [90]	validation_0-mlogloss:2.15893	validation_1-mlogloss:2.20443
# [100]	validation_0-mlogloss:2.15379	validation_1-mlogloss:2.2039
# [110]	validation_0-mlogloss:2.149	validation_1-mlogloss:2.20361
# [120]	validation_0-mlogloss:2.1443	validation_1-mlogloss:2.20335
# [130]	validation_0-mlogloss:2.13978	validation_1-mlogloss:2.20307
# [140]	validation_0-mlogloss:2.13543	validation_1-mlogloss:2.20301
# [150]	validation_0-mlogloss:2.13123	validation_1-mlogloss:2.20272
# [160]	validation_0-mlogloss:2.12699	validation_1-mlogloss:2.20255
# Stopping. Best iteration:
# [158]	validation_0-mlogloss:2.12779	validation_1-mlogloss:2.20253
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38283	validation_1-mlogloss:2.38374
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28586	validation_1-mlogloss:2.29319
# [20]	validation_0-mlogloss:2.23842	validation_1-mlogloss:2.25054
# [30]	validation_0-mlogloss:2.21217	validation_1-mlogloss:2.22915
# [40]	validation_0-mlogloss:2.19612	validation_1-mlogloss:2.21785
# [50]	validation_0-mlogloss:2.18501	validation_1-mlogloss:2.21174
# [60]	validation_0-mlogloss:2.17677	validation_1-mlogloss:2.20803
# [70]	validation_0-mlogloss:2.16991	validation_1-mlogloss:2.20516
# [80]	validation_0-mlogloss:2.16401	validation_1-mlogloss:2.20352
# [90]	validation_0-mlogloss:2.15874	validation_1-mlogloss:2.20275
# [100]	validation_0-mlogloss:2.15387	validation_1-mlogloss:2.20222
# [110]	validation_0-mlogloss:2.14917	validation_1-mlogloss:2.20152
# [120]	validation_0-mlogloss:2.14472	validation_1-mlogloss:2.20112
# [130]	validation_0-mlogloss:2.14048	validation_1-mlogloss:2.201
# [140]	validation_0-mlogloss:2.13638	validation_1-mlogloss:2.20041
# [150]	validation_0-mlogloss:2.13215	validation_1-mlogloss:2.20005
# [160]	validation_0-mlogloss:2.12825	validation_1-mlogloss:2.19951
# [170]	validation_0-mlogloss:2.12428	validation_1-mlogloss:2.19944
# [180]	validation_0-mlogloss:2.1205	validation_1-mlogloss:2.19937
# [190]	validation_0-mlogloss:2.11679	validation_1-mlogloss:2.19934
# [200]	validation_0-mlogloss:2.11303	validation_1-mlogloss:2.19934
# Stopping. Best iteration:
# [193]	validation_0-mlogloss:2.11565	validation_1-mlogloss:2.19925
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38284	validation_1-mlogloss:2.38355
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28572	validation_1-mlogloss:2.29268
# [20]	validation_0-mlogloss:2.23822	validation_1-mlogloss:2.25077
# [30]	validation_0-mlogloss:2.21212	validation_1-mlogloss:2.2299
# [40]	validation_0-mlogloss:2.19612	validation_1-mlogloss:2.21874
# [50]	validation_0-mlogloss:2.18528	validation_1-mlogloss:2.2123
# [60]	validation_0-mlogloss:2.17705	validation_1-mlogloss:2.20846
# [70]	validation_0-mlogloss:2.17036	validation_1-mlogloss:2.20612
# [80]	validation_0-mlogloss:2.1644	validation_1-mlogloss:2.20469
# [90]	validation_0-mlogloss:2.15911	validation_1-mlogloss:2.20385
# [100]	validation_0-mlogloss:2.15416	validation_1-mlogloss:2.20319
# [110]	validation_0-mlogloss:2.14943	validation_1-mlogloss:2.20271
# [120]	validation_0-mlogloss:2.145	validation_1-mlogloss:2.20203
# [130]	validation_0-mlogloss:2.14053	validation_1-mlogloss:2.2016
# [140]	validation_0-mlogloss:2.13628	validation_1-mlogloss:2.20118
# [150]	validation_0-mlogloss:2.13211	validation_1-mlogloss:2.20075
# [160]	validation_0-mlogloss:2.12826	validation_1-mlogloss:2.20058
# [170]	validation_0-mlogloss:2.1243	validation_1-mlogloss:2.20028
# Stopping. Best iteration:
# [168]	validation_0-mlogloss:2.12504	validation_1-mlogloss:2.20026
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38287	validation_1-mlogloss:2.38357
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28597	validation_1-mlogloss:2.29243
# [20]	validation_0-mlogloss:2.23842	validation_1-mlogloss:2.24992
# [30]	validation_0-mlogloss:2.21217	validation_1-mlogloss:2.2278
# [40]	validation_0-mlogloss:2.19621	validation_1-mlogloss:2.21647
# [50]	validation_0-mlogloss:2.18503	validation_1-mlogloss:2.20982
# [60]	validation_0-mlogloss:2.17679	validation_1-mlogloss:2.20606
# [70]	validation_0-mlogloss:2.17003	validation_1-mlogloss:2.20424
# [80]	validation_0-mlogloss:2.16413	validation_1-mlogloss:2.20283
# [90]	validation_0-mlogloss:2.15885	validation_1-mlogloss:2.20186
# [100]	validation_0-mlogloss:2.15396	validation_1-mlogloss:2.20095
# [110]	validation_0-mlogloss:2.14931	validation_1-mlogloss:2.20062
# [120]	validation_0-mlogloss:2.14479	validation_1-mlogloss:2.2001
# [130]	validation_0-mlogloss:2.14041	validation_1-mlogloss:2.19961
# [140]	validation_0-mlogloss:2.13622	validation_1-mlogloss:2.19959
# [150]	validation_0-mlogloss:2.13184	validation_1-mlogloss:2.19922
# [160]	validation_0-mlogloss:2.12767	validation_1-mlogloss:2.19865
# [170]	validation_0-mlogloss:2.1238	validation_1-mlogloss:2.19876
# Stopping. Best iteration:
# [160]	validation_0-mlogloss:2.12767	validation_1-mlogloss:2.19865
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38287	validation_1-mlogloss:2.3833
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28565	validation_1-mlogloss:2.29157
# [20]	validation_0-mlogloss:2.23818	validation_1-mlogloss:2.24954
# [30]	validation_0-mlogloss:2.21218	validation_1-mlogloss:2.22863
# [40]	validation_0-mlogloss:2.19608	validation_1-mlogloss:2.21793
# [50]	validation_0-mlogloss:2.18508	validation_1-mlogloss:2.21202
# [60]	validation_0-mlogloss:2.17694	validation_1-mlogloss:2.20892
# [70]	validation_0-mlogloss:2.17015	validation_1-mlogloss:2.20684
# [80]	validation_0-mlogloss:2.16425	validation_1-mlogloss:2.20555
# [90]	validation_0-mlogloss:2.15894	validation_1-mlogloss:2.20494
# [100]	validation_0-mlogloss:2.1538	validation_1-mlogloss:2.20403
# [110]	validation_0-mlogloss:2.14913	validation_1-mlogloss:2.20391
# [120]	validation_0-mlogloss:2.14466	validation_1-mlogloss:2.20388
# Stopping. Best iteration:
# [116]	validation_0-mlogloss:2.14641	validation_1-mlogloss:2.2037
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.3828	validation_1-mlogloss:2.38369
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28533	validation_1-mlogloss:2.29415
# [20]	validation_0-mlogloss:2.23776	validation_1-mlogloss:2.25248
# [30]	validation_0-mlogloss:2.21161	validation_1-mlogloss:2.23116
# [40]	validation_0-mlogloss:2.1955	validation_1-mlogloss:2.22001
# [50]	validation_0-mlogloss:2.18443	validation_1-mlogloss:2.21358
# [60]	validation_0-mlogloss:2.17635	validation_1-mlogloss:2.20981
# [70]	validation_0-mlogloss:2.16951	validation_1-mlogloss:2.20721
# [80]	validation_0-mlogloss:2.16366	validation_1-mlogloss:2.20528
# [90]	validation_0-mlogloss:2.15823	validation_1-mlogloss:2.20442
# [100]	validation_0-mlogloss:2.1533	validation_1-mlogloss:2.20381
# [110]	validation_0-mlogloss:2.14875	validation_1-mlogloss:2.20335
# [120]	validation_0-mlogloss:2.1442	validation_1-mlogloss:2.20281
# [130]	validation_0-mlogloss:2.13972	validation_1-mlogloss:2.20232
# [140]	validation_0-mlogloss:2.13542	validation_1-mlogloss:2.20205
# [150]	validation_0-mlogloss:2.13156	validation_1-mlogloss:2.20161
# [160]	validation_0-mlogloss:2.12754	validation_1-mlogloss:2.20117
# [170]	validation_0-mlogloss:2.12372	validation_1-mlogloss:2.20095
# [180]	validation_0-mlogloss:2.11998	validation_1-mlogloss:2.20053
# [190]	validation_0-mlogloss:2.11636	validation_1-mlogloss:2.20085
# Stopping. Best iteration:
# [180]	validation_0-mlogloss:2.11998	validation_1-mlogloss:2.20053
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38287	validation_1-mlogloss:2.38374
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28579	validation_1-mlogloss:2.29327
# [20]	validation_0-mlogloss:2.23809	validation_1-mlogloss:2.2514
# [30]	validation_0-mlogloss:2.212	validation_1-mlogloss:2.23018
# [40]	validation_0-mlogloss:2.19572	validation_1-mlogloss:2.21925
# [50]	validation_0-mlogloss:2.18468	validation_1-mlogloss:2.21323
# [60]	validation_0-mlogloss:2.17642	validation_1-mlogloss:2.21007
# [70]	validation_0-mlogloss:2.16967	validation_1-mlogloss:2.20813
# [80]	validation_0-mlogloss:2.16362	validation_1-mlogloss:2.20709
# [90]	validation_0-mlogloss:2.1582	validation_1-mlogloss:2.20615
# [100]	validation_0-mlogloss:2.15321	validation_1-mlogloss:2.20579
# [110]	validation_0-mlogloss:2.14853	validation_1-mlogloss:2.20522
# [120]	validation_0-mlogloss:2.14397	validation_1-mlogloss:2.2052
# [130]	validation_0-mlogloss:2.13976	validation_1-mlogloss:2.20499
# [140]	validation_0-mlogloss:2.13551	validation_1-mlogloss:2.20496
# Stopping. Best iteration:
# [133]	validation_0-mlogloss:2.13856	validation_1-mlogloss:2.20485
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.3828	validation_1-mlogloss:2.3835
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28562	validation_1-mlogloss:2.29326
# [20]	validation_0-mlogloss:2.23795	validation_1-mlogloss:2.25179
# [30]	validation_0-mlogloss:2.2116	validation_1-mlogloss:2.23083
# [40]	validation_0-mlogloss:2.19553	validation_1-mlogloss:2.22022
# [50]	validation_0-mlogloss:2.18433	validation_1-mlogloss:2.21451
# [60]	validation_0-mlogloss:2.17578	validation_1-mlogloss:2.21121
# [70]	validation_0-mlogloss:2.16871	validation_1-mlogloss:2.20898
# [80]	validation_0-mlogloss:2.16288	validation_1-mlogloss:2.20817
# [90]	validation_0-mlogloss:2.15765	validation_1-mlogloss:2.20753
# [100]	validation_0-mlogloss:2.15252	validation_1-mlogloss:2.20706
# [110]	validation_0-mlogloss:2.14773	validation_1-mlogloss:2.20684
# [120]	validation_0-mlogloss:2.14309	validation_1-mlogloss:2.20696
# Stopping. Best iteration:
# [117]	validation_0-mlogloss:2.14451	validation_1-mlogloss:2.20671
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38279	validation_1-mlogloss:2.38387
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.2856	validation_1-mlogloss:2.29421
# [20]	validation_0-mlogloss:2.23799	validation_1-mlogloss:2.25287
# [30]	validation_0-mlogloss:2.21157	validation_1-mlogloss:2.23193
# [40]	validation_0-mlogloss:2.19532	validation_1-mlogloss:2.22081
# [50]	validation_0-mlogloss:2.18423	validation_1-mlogloss:2.21525
# [60]	validation_0-mlogloss:2.17579	validation_1-mlogloss:2.2122
# [70]	validation_0-mlogloss:2.16895	validation_1-mlogloss:2.21016
# [80]	validation_0-mlogloss:2.16298	validation_1-mlogloss:2.20917
# [90]	validation_0-mlogloss:2.1575	validation_1-mlogloss:2.20867
# [100]	validation_0-mlogloss:2.15252	validation_1-mlogloss:2.20849
# [110]	validation_0-mlogloss:2.14779	validation_1-mlogloss:2.20837
# [120]	validation_0-mlogloss:2.14327	validation_1-mlogloss:2.20859
# Stopping. Best iteration:
# [114]	validation_0-mlogloss:2.14594	validation_1-mlogloss:2.20828
#
# ############## one flod is over ##############
# [0]	validation_0-mlogloss:2.38286	validation_1-mlogloss:2.38366
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [10]	validation_0-mlogloss:2.28572	validation_1-mlogloss:2.29366
# [20]	validation_0-mlogloss:2.23798	validation_1-mlogloss:2.25167
# [30]	validation_0-mlogloss:2.21172	validation_1-mlogloss:2.23088
# [40]	validation_0-mlogloss:2.19552	validation_1-mlogloss:2.21948
# [50]	validation_0-mlogloss:2.18461	validation_1-mlogloss:2.21335
# [60]	validation_0-mlogloss:2.1764	validation_1-mlogloss:2.20985
# [70]	validation_0-mlogloss:2.16966	validation_1-mlogloss:2.20775
# [80]	validation_0-mlogloss:2.16382	validation_1-mlogloss:2.20652
# [90]	validation_0-mlogloss:2.15844	validation_1-mlogloss:2.20571
# [100]	validation_0-mlogloss:2.15342	validation_1-mlogloss:2.2054
# [110]	validation_0-mlogloss:2.14869	validation_1-mlogloss:2.20529
# [120]	validation_0-mlogloss:2.1444	validation_1-mlogloss:2.20499
# [130]	validation_0-mlogloss:2.13996	validation_1-mlogloss:2.20448
# [140]	validation_0-mlogloss:2.13576	validation_1-mlogloss:2.20438
# [150]	validation_0-mlogloss:2.13166	validation_1-mlogloss:2.20446
# Stopping. Best iteration:
# [143]	validation_0-mlogloss:2.13456	validation_1-mlogloss:2.20415
#
# ############## one flod is over ##############

# %%
np.save('new_feature/age_train.npy',age_train)
np.save('new_feature/age_test.npy',age_test)

# %%
# sex num_class = 2
metric, sex_train, sex_test = xgbc_code(train_set, test_set, 'sex', 2, 10,
                                        'binary:logistic','logloss')
# Out:
# [0]	validation_0-logloss:0.685316	validation_1-logloss:0.685345
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.651996	validation_1-logloss:0.653425
# [20]	validation_0-logloss:0.645463	validation_1-logloss:0.648346
# [30]	validation_0-logloss:0.64332	validation_1-logloss:0.647397
# [40]	validation_0-logloss:0.642093	validation_1-logloss:0.647242
# Stopping. Best iteration:
# [39]	validation_0-logloss:0.642219	validation_1-logloss:0.647215
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685312	validation_1-logloss:0.685377
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.652051	validation_1-logloss:0.652878
# [20]	validation_0-logloss:0.645614	validation_1-logloss:0.647236
# [30]	validation_0-logloss:0.643564	validation_1-logloss:0.645948
# [40]	validation_0-logloss:0.642305	validation_1-logloss:0.645483
# [50]	validation_0-logloss:0.64125	validation_1-logloss:0.64531
# [60]	validation_0-logloss:0.640419	validation_1-logloss:0.645477
# Stopping. Best iteration:
# [50]	validation_0-logloss:0.64125	validation_1-logloss:0.64531
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.68529	validation_1-logloss:0.685477
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.65193	validation_1-logloss:0.653578
# [20]	validation_0-logloss:0.645553	validation_1-logloss:0.648037
# [30]	validation_0-logloss:0.643491	validation_1-logloss:0.647043
# [40]	validation_0-logloss:0.642266	validation_1-logloss:0.646393
# [50]	validation_0-logloss:0.6413	validation_1-logloss:0.646163
# [60]	validation_0-logloss:0.640499	validation_1-logloss:0.645968
# [70]	validation_0-logloss:0.639567	validation_1-logloss:0.646026
# Stopping. Best iteration:
# [68]	validation_0-logloss:0.639703	validation_1-logloss:0.645965
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.68529	validation_1-logloss:0.685505
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.651946	validation_1-logloss:0.653519
# [20]	validation_0-logloss:0.645446	validation_1-logloss:0.647925
# [30]	validation_0-logloss:0.643444	validation_1-logloss:0.646819
# [40]	validation_0-logloss:0.642142	validation_1-logloss:0.646303
# [50]	validation_0-logloss:0.641192	validation_1-logloss:0.646386
# Stopping. Best iteration:
# [42]	validation_0-logloss:0.641952	validation_1-logloss:0.646215
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685317	validation_1-logloss:0.68542
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.651912	validation_1-logloss:0.653479
# [20]	validation_0-logloss:0.645364	validation_1-logloss:0.648194
# [30]	validation_0-logloss:0.643399	validation_1-logloss:0.647331
# [40]	validation_0-logloss:0.642194	validation_1-logloss:0.646939
# [50]	validation_0-logloss:0.641242	validation_1-logloss:0.646841
# [60]	validation_0-logloss:0.640339	validation_1-logloss:0.646656
# [70]	validation_0-logloss:0.639559	validation_1-logloss:0.646637
# Stopping. Best iteration:
# [65]	validation_0-logloss:0.639863	validation_1-logloss:0.646495
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685315	validation_1-logloss:0.685369
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.651956	validation_1-logloss:0.65305
# [20]	validation_0-logloss:0.645462	validation_1-logloss:0.647513
# [30]	validation_0-logloss:0.643453	validation_1-logloss:0.646452
# [40]	validation_0-logloss:0.64225	validation_1-logloss:0.645998
# [50]	validation_0-logloss:0.641296	validation_1-logloss:0.64581
# [60]	validation_0-logloss:0.640638	validation_1-logloss:0.645729
# [70]	validation_0-logloss:0.639835	validation_1-logloss:0.64568
# Stopping. Best iteration:
# [66]	validation_0-logloss:0.640181	validation_1-logloss:0.645599
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685284	validation_1-logloss:0.685488
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.651857	validation_1-logloss:0.653928
# [20]	validation_0-logloss:0.645399	validation_1-logloss:0.648776
# [30]	validation_0-logloss:0.643342	validation_1-logloss:0.647765
# [40]	validation_0-logloss:0.642143	validation_1-logloss:0.647593
# [50]	validation_0-logloss:0.641231	validation_1-logloss:0.647382
# [60]	validation_0-logloss:0.640429	validation_1-logloss:0.647481
# Stopping. Best iteration:
# [50]	validation_0-logloss:0.641231	validation_1-logloss:0.647382
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685303	validation_1-logloss:0.685394
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.652008	validation_1-logloss:0.652779
# [20]	validation_0-logloss:0.645529	validation_1-logloss:0.647042
# [30]	validation_0-logloss:0.643468	validation_1-logloss:0.645833
# [40]	validation_0-logloss:0.642096	validation_1-logloss:0.645501
# [50]	validation_0-logloss:0.641068	validation_1-logloss:0.645357
# [60]	validation_0-logloss:0.640141	validation_1-logloss:0.645438
# Stopping. Best iteration:
# [51]	validation_0-logloss:0.640949	validation_1-logloss:0.645321
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685298	validation_1-logloss:0.685431
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.652006	validation_1-logloss:0.653037
# [20]	validation_0-logloss:0.645535	validation_1-logloss:0.647606
# [30]	validation_0-logloss:0.643368	validation_1-logloss:0.646758
# [40]	validation_0-logloss:0.642082	validation_1-logloss:0.646411
# [50]	validation_0-logloss:0.64112	validation_1-logloss:0.646326
# [60]	validation_0-logloss:0.640167	validation_1-logloss:0.646334
# Stopping. Best iteration:
# [51]	validation_0-logloss:0.641019	validation_1-logloss:0.646296
#
# ############## one flod is over ##############
# [0]	validation_0-logloss:0.685315	validation_1-logloss:0.685336
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.652121	validation_1-logloss:0.652634
# [20]	validation_0-logloss:0.645729	validation_1-logloss:0.646985
# [30]	validation_0-logloss:0.643674	validation_1-logloss:0.645669
# [40]	validation_0-logloss:0.642354	validation_1-logloss:0.645208
# [50]	validation_0-logloss:0.641476	validation_1-logloss:0.645147
# [60]	validation_0-logloss:0.640703	validation_1-logloss:0.645264
# Stopping. Best iteration:
# [50]	validation_0-logloss:0.641476	validation_1-logloss:0.645147
#
# ############## one flod is over ##############

# %%
np.save('new_feature/sex_train.npy',sex_train)
np.save('new_feature/sex_test.npy',sex_test)
